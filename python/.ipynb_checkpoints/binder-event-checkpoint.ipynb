# %%
import pandas as pd

# %%
pd.read_json("https://archive.analytics.mybinder.org/events-2022-09-01.jsonl",lines=True)
# Out:
#                       timestamp                        schema  version  \
# 0     2022-09-01 00:00:00+00:00  binderhub.jupyter.org/launch        5
# 1     2022-09-01 00:00:00+00:00  binderhub.jupyter.org/launch        5
# 2     2022-09-01 00:00:00+00:00  binderhub.jupyter.org/launch        5
# 3     2022-09-01 00:01:00+00:00  binderhub.jupyter.org/launch        5
# 4     2022-09-01 00:01:00+00:00  binderhub.jupyter.org/launch        5
# ...                         ...                           ...      ...
# 10153 2022-09-01 23:58:00+00:00  binderhub.jupyter.org/launch        5
# 10154 2022-09-01 23:58:00+00:00  binderhub.jupyter.org/launch        5
# 10155 2022-09-01 23:58:00+00:00  binderhub.jupyter.org/launch        5
# 10156 2022-09-01 23:58:00+00:00  binderhub.jupyter.org/launch        5
# 10157 2022-09-01 23:59:00+00:00  binderhub.jupyter.org/launch        5
#
#       provider                                               spec  \
# ...

# %% [markdown]
# # 在云端的jupyterlab无法爬取，不知是缺少包还是python版本的原因
